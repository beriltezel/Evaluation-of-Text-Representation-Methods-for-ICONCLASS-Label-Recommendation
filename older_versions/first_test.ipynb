# %%
from iconclass import init

# %%
ic = init()
a = ic["53A2"]

# %%
print(a)
# Out:
# 53A2

# %%
print(repr(a))
# Out:
# 53A2 Perseverance, Resolution, Determination; 'Perseveranza' (Ripa)

# %%
print(a())
# Out:
# Perseverance, Resolution, Determination; 'Perseveranza' (Ripa)

# %%
print(a('de'))
# Out:
# Beharrlichkeit, Unbeirrbarkeit, Zielstrebigkeit; Ripa: Perseveranza

# %%
for child in a:
    print(child('it'))
# Out:
# costanza, tenacia; 'Costanza', 'Tenacità' (Ripa)
# stabilità, fermezza; 'Fermezza, 'Stabilimento', 'Stabilità' (Ripa)
# perseveranza, risoluzione, determinazione; 'Perseveranza' (Ripa) (+ variante)
# perseveranza, risoluzione, determinazione; 'Perseveranza' (Ripa) (+ personificazione)
# perseveranza, risoluzione, determinazione; 'Perseveranza' (Ripa) (+ scena allegorica, p.es. due o più personificazioni implicate in un'azione)
# perseveranza, risoluzione, determinazione; 'Perseveranza' (Ripa) (+ rappresentazione simbolica di concetti)
# perseveranza, risoluzione, determinazione; 'Perseveranza' (Ripa) (+ rappresentazione emblematica di concetti)
# perseveranza, risoluzione, determinazione; 'Perseveranza' (Ripa) (+ 'exemplum', rappresentazione di evento (storico) esemplare)
# perseveranza, risoluzione, determinazione; 'Perseveranza' (Ripa) (+ situazione o evento (in particolare in dipinti di genere) con connotazioni simboliche)

# %%
for p in a.path():
    print(repr(p))
# Out:
# 5 Abstract Ideas and Concepts
# 53 Will, Volition
# 53A Characteristics of Will
# 53A2 Perseverance, Resolution, Determination; 'Perseveranza' (Ripa)

# %%
for child in a:
    print(child())
# Out:
# Constancy, Tenacity; 'Costanza', 'Tenacità' (Ripa)
# Stability, Firmness; 'Fermezza', 'Stabilimento', 'Stabilità' (Ripa)
# Perseverance, Resolution, Determination; 'Perseveranza' (Ripa) (+ variant)
# Perseverance, Resolution, Determination; 'Perseveranza' (Ripa) (+ personification)
# Perseverance, Resolution, Determination; 'Perseveranza' (Ripa) (+ allegorical scene, i.e. two or more personifications involved in an action)
# Perseverance, Resolution, Determination; 'Perseveranza' (Ripa) (+ symbolical representation of concept)
# Perseverance, Resolution, Determination; 'Perseveranza' (Ripa) (+ emblematical representation of concept)
# Perseverance, Resolution, Determination; 'Perseveranza' (Ripa) (+ 'exemplum', representation of exemplary (historical) event)
# Perseverance, Resolution, Determination; 'Perseveranza' (Ripa) (+ situation or event (especially in genre-painting) with symbolical connotation)

# %%
print(ic)
# Out:
# ICONCLASS

# %%
print(ic["0"]())
# Out:
# Abstract, Non-representational Art
